# %%
# Você decidiu juntar dinheiro para comprar um notebook de R$ 6.000. Todo mês consegue guardar 15% do seu salário líquido de R$ 2.000. 
# Em cada mês, primeiro guarde o valor mensal; em seguida, se for o caso, aplique as despesas e bônus. A cada 5 meses ocorre uma despesa fixa de R$ 300. 
# Além disso, a cada 8 meses você recebe um presente de uma tia de R$ 800, que é totalmente acrescentado ao valor acumulado. 
# Escreva um programa que calcule em quantos meses você atinge ou ultrapassa o valor de R$ 6.000 e informe também quanto dinheiro sobra após atingir a meta. Use necessariamente while.
x = 0
mes = 0

while x < 6000:
    mes = mes + 1
    x = x + 300     
    if mes % 5 == 0:
        x = x - 300     
    if mes % 8 == 0:
        x = x + 800     

print("Meses necessários:", mes)
print("Sobra após atingir a meta:", x - 6000)
# Out:
# Meses necessários: 18
# Sobra após atingir a meta: 100

# %%
# Implemente uma função em Python chamada conta_pulo(s) que recebe uma string s. 
# A função deve contar quantas vezes o padrão "p*lo" aparece na string, onde o caractere "*" pode ser qualquer letra ou símbolo. 
# Exemplos: "pulo", "palo" e "p#lo" devem ser contabilizados. Regra: A busca deve diferenciar maiúsculas de minúsculas (ex: "Pulo" não conta). 
# Requisito: Use um laço de repetição e fatiamento (slicing) para percorrer a string, garantindo que o índice não ultrapasse o tamanho do texto.

def conta_pulo(s):
    contador = 0
    i = 0
    while i + 4 <= len(s):
        janela = s[i:i+4]
        if janela[0] == "p" and janela[2] == "l" and janela[3] == "o":
            contador = contador + 1
        i = i + 1
    return contador

print(conta_pulo('pwlo'))
# Out:
# 1

# %%
#Seja um dicionário de alunos, com suas notas. Mostre os alunos em ordem crescente de nota.

alunos = {'jose': 10, 'maria': 7, 'ulisses': 8}
ordenados = {aluno: nota for aluno, nota in sorted(alunos.items(), key=lambda item: item[1])}
print(ordenados)
# Out:
# {'maria': 7, 'ulisses': 8, 'jose': 10}

# %%
#Faça uma função recursiva que calcule o Fibonacci de um inteiro positivo n. Ex: fib(1)=1 etc
#Retorne o valor da posição, não a sequência inteira 

from functools import cache
@cache
def fib(n):
    if n==1 or n==2: return 1
    return fib(n-1)+fib(n-2)
print (fib(7))
# Out:
# 13
